# %% [markdown]
# ## Decision Tree's: Best and Worse Practices
#
# Week 11 | Sample Lesson
#
# creator: Joe Klein
#
#
# ## Learning Objectives
#
# ---
#
# _After this lesson, you should be able to:_ Determine when a decision tree is the appropriate method to use.
# - Understand the limitations of decision tress.
# - List use cases: Classification, Regression (CART)
# - Know the positive and negative takeaways from Decision Trees
#
#
# ## Student Pre-work
#
# ---
#
# _Before this lesson, you should already be able to:_
# - **Machine Learning:** Basice understanding of Linear and Logistic Regression, or the difference between regression models and classification models.
#
# ## Instructor Prep
# ---
#
# _Before this lesson, instructors will need to:_ Have activity planned out, and understanding of benefits and shortcoming of Decision Trees to explain the reasoning behind the activity.
#
#
# ### LESSON GUIDE
# ---
#
# | **TIMING**  | **TYPE**  | **TOPIC**  |
# |:-:|---|---|
# | 2 min  | Introduction  | Decision Tree Use Cases  |
# | 3 min  | Explain Skill  | CART  |
# | 5 min  | Practice Skill Together  | Decision Tree Process  |
# | 5 min | Access, Debreif, & Correct | Lesson and Activity Key Takeaways|
#
#
# ***
# ***
# ### Introduction: Decision Tree Use Cases (2 min)
# ---
#
# Recall your knowledge on the differences between Regression and Classification:
#
# **Check:** Name a Regression modeling technique? Name a Classification modeling technique?
#
# Decision Trees are also known as CART:
# -    **C**lassification
# -    **A**nd
# -    **R**egression
# -    **T**rees
#
# The term Classification And Regression Tree (CART) analysis is an umbrella term used to refer to both of the above procedures, first introduced by Breiman et al. Trees used for regression and trees used for classification have some similarities - but also some differences, such as the procedure used to determine where to split.
#
# ### Explain Skill: CART (3 min)
# ---
#
# **Recap:**
#
# - Classification: Decision Trees can be used for classification data.
#
# - Regression (Numerical): Decisions Trees to identify a continuous target variable.
# <br>
# <br>
# ![Regression vs. Clasification](assets/Figure-2-Illustration-of-the-difference-between-regression-and-classification.png "Mattermost Icon")
#
# #### Simple Answer: Whenever
#   - Easy to understand
#   - Work for classification and regression
#   - Nonparametric (Does not make any underlying assumptions of data)
#
# #### Realistic Answer: Rarely… to never
#    - Not robust modeling technique
#    - Reacts poorly with changed data
#    - Decision trees are weak learners that are easy to overfit
#
#
# ### Practice Skill Together (5 min)
# ---
# **Do I go out for lunch?**
# _Order by importance_
#
# - Appetite (Hungry or Full)
# - Time (Do I have time)
# - Money (Do I want to spend the money)
# - Weather (Is it raining or sunny)
# - Special Promotion (New deal you may want)
#
#
# ### Access, Debreif, & Correct (5 min)
# ---
#
# **Key Positives Takeaways of CART:**
# - Good at clearly identifying important features
# - Easy to describe, process is similar to how a person might make a decision
#
# **Key Negative Takeaways of CART**
# <br>
# _There are more than positives_
# - One feature can dominate (e.g. if you have no money)
#    - Non-robust
#    - Extremely sensitive
# - Decision trees are weak learners that are easy to overfit
#    - Can tree prun this can be a labor intensive process
# - **Multicolinearity**
#     - when two variables both explain the same thing
#     - a decision tree will greedily choose the best one, whereas many other methods will use them both.
